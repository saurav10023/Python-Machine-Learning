# %%
import numpy as np
import pandas as pd 
from io import StringIO
data = '[{"employee_name": "james", "role": "developer", "salary": 5000},{"employee_name": "sarah", "role": "manager", "salary": 8000}]'
df = pd.read_json(StringIO(data)) 
df.to_json()
print(df)
# Out:
#   employee_name       role  salary
# 0         james  developer    5000
# 1         sarah    manager    8000

# %%
df.to_json()
# Out:
# '{"employee_name":{"0":"james","1":"sarah"},"role":{"0":"developer","1":"manager"},"salary":{"0":5000,"1":8000}}'

# %%
df.to_json( orient='records')
# Out:
# '[{"employee_name":"james","role":"developer","salary":5000},{"employee_name":"sarah","role":"manager","salary":8000}]'

# %%
df.to_json( orient='index')
# Out:
# '{"0":{"employee_name":"james","role":"developer","salary":5000},"1":{"employee_name":"sarah","role":"manager","salary":8000}}'
