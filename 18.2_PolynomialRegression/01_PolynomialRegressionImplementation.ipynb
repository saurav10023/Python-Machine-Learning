# %% [markdown]
# ## Polynomial regression Implementation

# %%
import numpy as np  
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = 6*np.random.rand(100,1) -3 
y = 0.5 * x**2 + 1.5*x +2 + np.random.randn(100,1)

## quadratic equation used - y=0.5x^2 + 1.5X+2+outliers
plt.scatter(x,y,color='r')
plt.xlabel('X dataset')
plt.ylabel('Y dataset')
plt.show()

# %%
from sklearn.model_selection import train_test_split 
x_train , x_test , y_train , y_test = train_test_split(x,y, test_size=0.2 , random_state=42)

# %%
### implement a simple linear regression  

from sklearn.linear_model import LinearRegression 
regression_1 = LinearRegression()

# %%
regression_1.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score 
r2_score1 = r2_score(y_test , regression_1.predict(x_test))
r2_score1
# Out:
# 0.7975506569734755

# %%
plt.plot(x_train , regression_1.predict(x_train) , color='r')
plt.scatter(x_train , y_train)
plt.xlabel("X Data Set")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ## Now PolyNomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures 
poly=PolynomialFeatures(degree=2 , include_bias=True)

# %%
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

# %%
x_train_poly
# Out:
# array([[ 1.00000000e+00,  2.27699091e-01,  5.18468760e-02],
#        [ 1.00000000e+00,  1.56036771e+00,  2.43474740e+00],
#        [ 1.00000000e+00, -1.12760069e+00,  1.27148331e+00],
#        [ 1.00000000e+00,  7.11887794e-01,  5.06784231e-01],
#        [ 1.00000000e+00, -7.44937798e-01,  5.54932323e-01],
#        [ 1.00000000e+00, -2.83869107e-01,  8.05816697e-02],
#        [ 1.00000000e+00, -2.96524699e+00,  8.79268971e+00],
#        [ 1.00000000e+00,  3.78157862e-01,  1.43003369e-01],
#        [ 1.00000000e+00,  2.20233492e+00,  4.85027908e+00],
#        [ 1.00000000e+00,  1.78365706e-01,  3.18143249e-02],
#        [ 1.00000000e+00, -6.63156585e-01,  4.39776656e-01],
#        [ 1.00000000e+00,  2.39620370e+00,  5.74179216e+00],
#        [ 1.00000000e+00, -2.19158859e-01,  4.80306053e-02],
#        [ 1.00000000e+00, -2.59983103e+00,  6.75912139e+00],
#        [ 1.00000000e+00, -1.40707800e+00,  1.97986851e+00],
#        [ 1.00000000e+00, -1.09932137e+00,  1.20850747e+00],
# ...

# %%
x_test_poly
# Out:
# array([[ 1.00000000e+00,  1.07717327e-01,  1.16030225e-02],
#        [ 1.00000000e+00, -5.46698887e-01,  2.98879673e-01],
#        [ 1.00000000e+00,  1.78487182e-01,  3.18576741e-02],
#        [ 1.00000000e+00,  2.18103311e+00,  4.75690542e+00],
#        [ 1.00000000e+00, -2.17325036e+00,  4.72301715e+00],
#        [ 1.00000000e+00, -1.18851496e+00,  1.41256782e+00],
#        [ 1.00000000e+00, -2.23867611e+00,  5.01167071e+00],
#        [ 1.00000000e+00, -2.10747022e+00,  4.44143073e+00],
#        [ 1.00000000e+00, -1.90484537e+00,  3.62843588e+00],
#        [ 1.00000000e+00, -1.75832140e+00,  3.09169416e+00],
#        [ 1.00000000e+00,  2.60396593e+00,  6.78063855e+00],
#        [ 1.00000000e+00, -1.38106871e+00,  1.90735077e+00],
#        [ 1.00000000e+00,  1.04997569e-01,  1.10244895e-02],
#        [ 1.00000000e+00,  2.25713174e+00,  5.09464369e+00],
#        [ 1.00000000e+00, -1.56017851e-02,  2.43415700e-04],
#        [ 1.00000000e+00, -1.17955446e+00,  1.39134872e+00],
# ...

# %%
from sklearn.metrics import r2_score 
regression_poly = LinearRegression()
regression_poly.fit(x_train_poly , y_train)
y_pred2 = regression_poly.predict(x_test_poly)
score2 = r2_score(y_test , y_pred2)
print(score2)
# Out:
# 0.9460692042126676

# %%
print(regression_poly.coef_)
# Out:
# [[0.         1.50652495 0.52148781]]

# %%
plt.scatter(x_train , regression_poly.predict(x_train_poly))
plt.scatter(x_train , y_train , color='r')

# %%
## 3 prediction of new data set 

x_new = np.linspace(-3, 3, 200).reshape(200,1)
x_new_poly = poly.transform(x_new)
x_new_poly
# Out:
# array([[ 1.00000000e+00, -3.00000000e+00,  9.00000000e+00],
#        [ 1.00000000e+00, -2.96984925e+00,  8.82000455e+00],
#        [ 1.00000000e+00, -2.93969849e+00,  8.64182723e+00],
#        [ 1.00000000e+00, -2.90954774e+00,  8.46546804e+00],
#        [ 1.00000000e+00, -2.87939698e+00,  8.29092700e+00],
#        [ 1.00000000e+00, -2.84924623e+00,  8.11820409e+00],
#        [ 1.00000000e+00, -2.81909548e+00,  7.94729931e+00],
#        [ 1.00000000e+00, -2.78894472e+00,  7.77821267e+00],
#        [ 1.00000000e+00, -2.75879397e+00,  7.61094417e+00],
#        [ 1.00000000e+00, -2.72864322e+00,  7.44549380e+00],
#        [ 1.00000000e+00, -2.69849246e+00,  7.28186157e+00],
#        [ 1.00000000e+00, -2.66834171e+00,  7.12004747e+00],
#        [ 1.00000000e+00, -2.63819095e+00,  6.96005151e+00],
#        [ 1.00000000e+00, -2.60804020e+00,  6.80187369e+00],
#        [ 1.00000000e+00, -2.57788945e+00,  6.64551400e+00],
#        [ 1.00000000e+00, -2.54773869e+00,  6.49097245e+00],
# ...

# %%
y_new = regression_poly.predict(x_new_poly)
# Polynomial regression curve
plt.plot(x_new, y_new, "r-", linewidth=3, label="Polynomial Regression")

# Training data
plt.scatter(x_train, y_train, color="blue", s=30, label="Training points")

# Testing data
plt.scatter(x_test, y_test, color="green", s=30, label="Testing points")

plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
def poly_regression(degree) :
    x_new = np.linspace(-3,3,200).reshape(200,1)

    poly

# %% [markdown]
# ## Piepline in Polynomial Regression

# %%
from sklearn.pipeline import Pipeline

# %%
def poly_regression(degree):
    X_new = np.linspace(-3, 3, 200).reshape(200, 1)
    
    poly_features=PolynomialFeatures(degree=degree,include_bias=True)
    lin_reg=LinearRegression()
    poly_regression=Pipeline([
        ("poly_features",poly_features),
        ("lin_reg",lin_reg)
    ])
    poly_regression.fit(x_train,y_train) ## ploynomial and fit of linear reression
    y_pred_new=poly_regression.predict(X_new)
    #plotting prediction line
    plt.plot(x_new, y_pred_new,'r', label="Degree " + str(degree), linewidth=2)
    plt.plot(x_train, y_train, "b.", linewidth=3)
    plt.plot(x_test, y_test, "g.", linewidth=3)
    plt.legend(loc="upper left")
    plt.xlabel("X")
    plt.ylabel("y")
    plt.axis([-4,4, 0, 10])
    plt.show()

    return lin_reg

# %%
poly_regression(10)
