# %% [markdown]
# # logging is a crucial aspect of any application , providing a way to track events  , errors and operational information . python's builtin logging modules offers flexible frame work for emitting log message from python programs .

# %%
import logging as log  
#config the basic logging settings 
log.basicConfig(level=log.DEBUG)

# log messages 
log.debug("this is a debug message ")
log.info("this is a info message ")
log.warning("this is warning ")
log.error("this is a error message")
log.critical("this is a critical message")
# Out:
# DEBUG:root:this is a debug message
# INFO:root:this is a info message
# WARNING:root:this is warning
# ERROR:root:this is a error message
# CRITICAL:root:this is a critical message

# %% [markdown]
# # log leveles
# debug : detailed info , typically of the intrest only when diagnosing problems
# info : confirmation that things are working as expected
# warning : an indication that something unexpected happened or indicative of some problem in near future
# software is still able to perform
# error: due to more serious problem the software is not able to perform some functions
# critical: very serious error , indicating that the problem itself may be unable to continue running

# %%
import logging 
## create a logger for module 1 
logger1 = logging.getLogger('module1')
logger1.setLevel(logging.DEBUG)

#create a logger for module 2
logger2 = logging.getLogger('module2')
logger2.setLevel(logging.WARNING)

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
logger1.debug("this is debug message for module1")
logger2.warning("this is warning for module2")
logger2.error("this is an error message")
# Out:
# 2026-01-30 00:07:21 - module1 - this is debug message for module1
# 2026-01-30 00:07:21 - module2 - this is warning for module2
# 2026-01-30 00:07:21 - module2 - this is an error message
