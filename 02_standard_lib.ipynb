# %% [markdown]
# ##standard python libraries

# %%
import math
import random

# %%
## File and directory access

import os 
print(os.getcwd())  ##for current working directory
# Out:
# c:\Users\saura\Desktop\VS CODE FILES\python ml

# %%
os.makedirs('test_dir')
##creates folder

# %%
## high level operations on files and collection of files
import shutil 
shutil.copyfile('requirment.txt' , 'copied.txt')
# Out:
# 'copied.txt'

# %%
## data sterlization
import json

data= {'name': 'saurav' , 'age':20}
json_string = json.dumps(data)
print((json_string))
print(type(json_string))

passed_data = json.loads(json_string)
print(passed_data)
print(type(passed_data))
# Out:
# {"name": "saurav", "age": 20}
# <class 'str'>
# {'name': 'saurav', 'age': 20}
# <class 'dict'>

# %%
### csv 
import csv 

with open('example.csv' , mode = 'w' , newline= '') as file :
    writer = csv.writer(file)
    writer.writerow(['name' , 'age'])
    writer.writerow(['saurav' , 20])

with open('example.csv' , mode='r') as file :
    reader = csv.reader(file)
    for row in reader :
        print(row)
# Out:
# ['name', 'age']
# ['saurav', '20']

# %%
## date time 
from datetime import datetime , timedelta 

now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2025-12-01 14:38:05.060918
# 2025-11-30 14:38:05.060918

# %%
## time 
import time 
print(time.time())

time.sleep(2)
print(time.time())
# Out:
# 1764580140.3077989
# 1764580142.3172638

# %%
## regular expression
##helps to match specific sections in a top of a sentence or any other data set

import re
pattern = r'\d+'

text = 'there are 123 apples 234 bananas'
match = re.search(pattern , text )
print(match.groups())
# Out:
# ()
