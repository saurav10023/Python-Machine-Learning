# %%
#iterator 
my_list = [1,2,3,4,5,6]
iterator = iter(my_list)
print(iterator)
# Out:
# <list_iterator object at 0x00000223B2415540>

# %%
print(next(iterator))
# Out:
# 1

# %%
try:
    print(next(iterator))
except StopIteration:
    print('There are no elements in the iterator.')
# Out:
# 4

# %% [markdown]
# ## Generators provide a simple way to create iterators by using the yield keyword to produce a series of values lazily. This means they generate values on the fly and do not store them in memory, enabling efficient memory management during looping.

# %%
def square(n):
    for i in range(n):
        return i * 2

# %%
def square(n):
    for i in range(n):
        yield i * 2

gen = square(3)
print(gen)  # Output: <generator object square at 0x...>
for i in square(3):
    print(i)
# Out:
# 0
# 2
# 4

# %%
a = square(3)
print(next(a))  # Output: 0
print(next(a))  # Output: 2
print(next(a))  # Output: 4
print(next(a))  # Raises StopIteration

# %% [markdown]
# ## practical examples of reading large file
# Generators are particularly useful for reading large files because they allow processing one line at a time without loading the entire file into memory. This efficient approach helps manage memory usage when dealing with large datasets

# %%
def read_large_file(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line

file_path = 'destinstion.txt'
for line in read_large_file(file_path):
    print(line.strip())
# Out:
# scikit-learn
#
# hello hi
# i am fine

# %% [markdown]
# ## function copy
# Function copy in Python refers to assigning a function to another variable. This allows the function to be called using the new variable, even if the original function is deleted

# %%
def welcome():
    return "Welcome to the Advanced Python course"

well = welcome
print(well())
del welcome
print(well())
# Out:
# Welcome to the Advanced Python course
# Welcome to the Advanced Python course

# %% [markdown]
# ## Closures in Python
# A closure is a function defined inside another function, which can access variables from the enclosing function's scope. This is similar to concepts in other languages like C# and Java

# %%
def main_welcome():
    message = "Welcome"
    def sub_welcome():
        print("Welcome to the Advanced Python course")
        print("Please learn this concepts properly")
        print(message)
    return sub_welcome

closure_func = main_welcome()
closure_func()
# Out:
# Welcome to the Advanced Python course
# Please learn this concepts properly
# Welcome

# %% [markdown]
# ## Introduction to Decorators
# Decorators are a powerful and flexible feature in Python that allow you to modify the behavior of a function or class method. They are commonly used to add functionality to functions or methods without modifying the actual code

# %%
def main_welcome(func):
    def sub_welcome():
        print("Welcome to the Advanced Python course")
        func()
        print("Please learn this concepts properly")
    return sub_welcome

# %%
def course_introduction():
    print("This is an advanced Python course")

# %%
@main_welcome  ## decorator key word using this  we can directly use the parameter function below
def course_introduction():
    print("This is an advanced Python course")

course_introduction()
# Out:
# Welcome to the Advanced Python course
# This is an advanced Python course
# Please learn this concepts properly

# %%
def repeat(n):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(n):
                func(*args, **kwargs)
        return wrapper
    return decorator

@repeat(3)
def say_hello():
    print("Hello")

# %%
say_hello()
# Out:
# Hello
# Hello
# Hello
